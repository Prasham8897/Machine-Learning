# %% [markdown]
# # Problem 1 (Markov chains)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("CFB2019_scores.csv",header=None)

# %%
data["winA"] = [1 if data[1][i] > data[3][i] else 0 for i in range(len(data))]
data["winB"] = [1 if data[1][i] < data[3][i] else 0 for i in range(len(data))]

# %%
M_hat = np.zeros(shape=(769,769))

# %%
for _,row in data.iterrows():
    i = row[0] - 1
    j = row[2] - 1
    pointsA = row[1]
    pointsB = row[3]
    winA = row["winA"]
    winB = row["winB"]
    incA = (pointsA / (pointsA + pointsB))
    incB = (pointsB / (pointsA + pointsB))
    M_hat[i][i]+=(winA + incA)
    M_hat[j][j]+=(winB + incB)
    M_hat[i][j]+=(winB + incB)
    M_hat[j][i]+=(winA + incA)

# %%
row_sums = np.sum(M_hat,axis=1)
M = M_hat / row_sums[:, np.newaxis]
M1 = M

# %%
# w_0 = np.full(shape=(1,769),fill_value = 1/769)
np.random.seed(0)
w_0 = np.random.uniform(0,1,size=769)
w_0 /= np.sum(w_0)
# w_0 = w_0.reshape(1,769)

# %%
w, v = np.linalg.eig(M.T)
index = np.argmax(w)
v_1 = v[:,index]
# .reshape(769,1)
# print("The value of Eigen value is " + str(round(w[index],2)))
# print("The value of V_transpose * V is " + str(np.matmul(v_1.T,v_1)[0][0]))

# %%
w_inf = np.real(v_1.T/np.sum(v_1))

# %%
plot1 = []
T = [10,100,1000,10000]
values = dict()
positions = dict()
for i in range(1,10001):
    temp = np.matmul(w_0,M)
    w_0 = temp
    plot1.append(np.linalg.norm((temp - w_inf),ord=1))
    if i in T:
        values[i] = temp

# %%
plt.plot(range(1,10001),plot1)
plt.title("Plot of the first order norm of ||w_t - w_inf|| as a function of t")
plt.xlabel("t")
plt.ylabel("value of the norm")
plt.show()

# %%
for i in list(values.keys()):
    positions[i] = np.argsort(-values[i])
    positions[i] = positions[i].tolist()[:25]
    values[i] = -np.sort(-values[i])
    values[i] = values[i].tolist()[:25]

# %%
filename = "TeamNames.txt"
names=[]
for i in open(filename,"r"):
    names.append(i.strip())
names=np.array(names)

# %%
for t in T:
    print("-------------------------------------------------------------------------")
    print("Top 25 teams for t = " + str(t))
    print("-------------------------------------------------------------------------")
    temp = pd.DataFrame({"Name":names[positions[t]].tolist(),"Value in W_t":values[t]})
    print(temp)
    print("-------------------------------------------------------------------------")
# Out:
# -------------------------------------------------------------------------
# Top 25 teams for t = 10
# -------------------------------------------------------------------------
#                  Name  Value in W_t
# 0        NorthCentral      0.013785
# 1                 LSU      0.012375
# 2             Wheaton      0.012000
# 3         Morningside      0.010047
# 4       NorthDakotaSt      0.009649
# 5       UW-Whitewater      0.009641
# 6          MountUnion      0.009357
# 7      MinnSt-Mankato      0.009314
# 8           OhioState      0.009227
# 9          Muhlenberg      0.009114
# 10        WestFlorida      0.009005
# 11            Clemson      0.008778
# 12          StJohnsMN      0.008640
# 13  MaryHardin-Baylor      0.008331
# 14           FerrisSt      0.007726
# 15           MarianIN      0.007341
# 16            Georgia      0.006735
# 17          GrandView      0.006681
# 18       SlipperyRock      0.006028
# 19         ValdostaSt      0.006000
# 20             Oregon      0.005919
# 21           Wartburg      0.005709
# 22     DelawareValley      0.005580
# 23            UnionNY      0.005528
# 24       Lenoir-Rhyne      0.005454
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Top 25 teams for t = 100
# -------------------------------------------------------------------------
#               Name  Value in W_t
# 0              LSU      0.043520
# 1          Wheaton      0.026537
# 2     NorthCentral      0.025048
# 3          Clemson      0.023639
# 4        OhioState      0.022626
# 5      Morningside      0.021715
# 6          Georgia      0.017115
# 7        StJohnsMN      0.015441
# 8      WestFlorida      0.013548
# 9    UW-Whitewater      0.013204
# 10         Alabama      0.012882
# 11         Florida      0.012404
# 12      Muhlenberg      0.011386
# 13          Oregon      0.010500
# 14          Auburn      0.009992
# 15        Oklahoma      0.009982
# 16  MinnSt-Mankato      0.009875
# 17       PennState      0.009508
# 18        MarianIN      0.009144
# 19      ValdostaSt      0.009002
# 20    Lenoir-Rhyne      0.008150
# 21       Wisconsin      0.007996
# 22       NotreDame      0.007843
# 23      MountUnion      0.007602
# 24       Minnesota      0.007510
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Top 25 teams for t = 1000
# -------------------------------------------------------------------------
#              Name  Value in W_t
# 0             LSU      0.084615
# 1         Clemson      0.045633
# 2       OhioState      0.043553
# 3         Georgia      0.032796
# 4         Alabama      0.024736
# 5         Florida      0.023752
# 6          Oregon      0.019311
# 7          Auburn      0.019081
# 8        Oklahoma      0.018747
# 9       PennState      0.018016
# 10      Wisconsin      0.015201
# 11      NotreDame      0.014682
# 12      Minnesota      0.014234
# 13         Baylor      0.012734
# 14       Michigan      0.012073
# 15           Utah      0.011730
# 16        Memphis      0.011691
# 17           Iowa      0.011032
# 18  AppalachianSt      0.010949
# 19          Texas      0.010211
# 20  NorthDakotaSt      0.009249
# 21           Navy      0.009093
# 22       TexasA&M      0.008954
# 23        BoiseSt      0.008326
# 24       KansasSt      0.007352
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Top 25 teams for t = 10000
# -------------------------------------------------------------------------
#              Name  Value in W_t
# 0             LSU      0.091674
# 1         Clemson      0.049428
# 2       OhioState      0.047168
# 3         Georgia      0.035501
# 4         Alabama      0.026785
# 5         Florida      0.025711
# 6          Oregon      0.020849
# 7          Auburn      0.020652
# 8        Oklahoma      0.020270
# 9       PennState      0.019494
# 10      Wisconsin      0.016447
# 11      NotreDame      0.015874
# 12      Minnesota      0.015399
# 13         Baylor      0.013763
# 14       Michigan      0.013067
# 15           Utah      0.012659
# 16        Memphis      0.012632
# 17           Iowa      0.011934
# 18  AppalachianSt      0.011832
# 19          Texas      0.011040
# 20           Navy      0.009818
# 21  NorthDakotaSt      0.009749
# 22       TexasA&M      0.009690
# 23        BoiseSt      0.008974
# 24       KansasSt      0.007942
# -------------------------------------------------------------------------

# %% [markdown]
# # Problem 2 (Nonnegative matrix factorization)

# %%
N = 3012
M = 8447

# %%
num_iter = 100
rank = 25

# %%
X = np.zeros(shape=(N,M))
np.random.seed(0)
W = np.random.uniform(1,2,size=(N,rank))
H = np.random.uniform(1,2,size=(rank,M))

# %%
filename = "nyt_data.txt"

# %%
doc_index = 0
for i in open(filename,"r"):
    row = (i.strip().split(","))
    for element in row:
        temp = element.split(":")
        X[int(temp[0])-1][doc_index]= int(temp[1])
    doc_index+=1

# %%
objective = []
for run in range(num_iter):
    X_WH = np.divide(X,(np.matmul(W,H)+10**-16))
    W_T = W.T
    row_sums = np.sum(W_T,axis=1)
    normalized_W_T =  W_T / (row_sums[:, np.newaxis] + 10**-16)
    second_term = np.matmul(normalized_W_T,X_WH)
    H = np.multiply(H,(second_term))
    
    X_WH = np.divide(X,(np.matmul(W,H)+10**-16))
    H_T = H.T
    col_sums = np.sum(H_T,axis=0)
    normalized_H_T =  H_T / (col_sums + 10**-16)
    second_term = np.matmul(X_WH,normalized_H_T)
    W = np.multiply(W,(second_term))
    
    WH = np.matmul(W,H)
    log_WH = np.log(WH+ 10**-16) 
    temp = np.multiply(X,log_WH) - WH
    objective_value = -np.sum(temp)
    objective.append(objective_value)

# %%
plt.plot(range(1,101),objective)
plt.title("Plot for objective")
plt.xlabel("Iterations")
plt.ylabel("value of the objective")
plt.show()

# %%
col_sums = np.sum(W,axis=0)
normalized_W =  W / (col_sums + 10**-16)

# %%
filename = "nyt_vocab.dat"
names=[]
for i in open(filename,"r"):
    names.append(i.strip())
names=np.array(names)

# %%
positions = dict()
values = dict()
list_topic_word = dict()
for i in range(rank):
    positions[i] = np.argsort(-normalized_W[:,i])
    positions[i] = positions[i].tolist()[:10]
    positions[i] = [names[j] for j in positions[i]]
    values[i] = -np.sort(-normalized_W[:,i])
    values[i] = values[i].tolist()[:10]

# %%
answer = dict()
for i in range(25):
    text=""
    for j in range(10):
        text+= positions[i][j] + " : " +str(round(values[i][j],2)) + "\n"
    answer[i]=text[:-1]

# %%
for i in range(25):
    print(i+1)
    print("---------------------------")
    print(answer[i])
    print("---------------------------")
# Out:
# 1
# ---------------------------
# sell : 0.02
# sale : 0.02
# company : 0.02
# store : 0.02
# buy : 0.02
# price : 0.01
# business : 0.01
# cost : 0.01
# industry : 0.01
# customer : 0.01
# ---------------------------
# 2
# ---------------------------
# school : 0.03
# student : 0.03
# child : 0.01
# program : 0.01
# class : 0.01
# education : 0.01
# college : 0.01
# group : 0.01
# teacher : 0.01
# community : 0.01
# ---------------------------
# 3
# ---------------------------
# police : 0.03
# kill : 0.02
# officer : 0.02
# man : 0.02
# charge : 0.02
# crime : 0.01
# arrest : 0.01
# death : 0.01
# official : 0.01
# victim : 0.01
# ---------------------------
# 4
# ---------------------------
# father : 0.06
# son : 0.05
# mrs : 0.04
# mother : 0.04
# daughter : 0.04
# graduate : 0.03
# family : 0.03
# marry : 0.02
# receive : 0.02
# retire : 0.02
# ---------------------------
# 5
# ---------------------------
# cause : 0.01
# problem : 0.01
# damage : 0.01
# plant : 0.01
# water : 0.01
# official : 0.01
# report : 0.01
# scientist : 0.01
# safety : 0.01
# system : 0.01
# ---------------------------
# 6
# ---------------------------
# official : 0.02
# military : 0.01
# american : 0.01
# states : 0.01
# war : 0.01
# force : 0.01
# meeting : 0.01
# government : 0.01
# nations : 0.01
# agreement : 0.01
# ---------------------------
# 7
# ---------------------------
# pay : 0.02
# money : 0.02
# state : 0.01
# budget : 0.01
# bill : 0.01
# tax : 0.01
# program : 0.01
# cut : 0.01
# plan : 0.01
# cost : 0.01
# ---------------------------
# 8
# ---------------------------
# food : 0.02
# fresh : 0.01
# serve : 0.01
# pound : 0.01
# eat : 0.01
# restaurant : 0.01
# taste : 0.01
# dry : 0.01
# cook : 0.01
# fish : 0.01
# ---------------------------
# 9
# ---------------------------
# music : 0.02
# play : 0.02
# performance : 0.01
# perform : 0.01
# stage : 0.01
# production : 0.01
# theater : 0.01
# dance : 0.01
# song : 0.01
# audience : 0.01
# ---------------------------
# 10
# ---------------------------
# team : 0.04
# player : 0.02
